# %%
import pandas as pd
import numpy as np

# %%
a1 = pd.read_excel('C:/Users/이민정/OneDrive/바탕 화면/mid project/음주운전 관련 데이터/음주_교통사고_15-19.xls')
display(a1)
# Out:
#                                                     시도      시군구   2015 2015.1  \
# 0                                                   시도      시군구  사고[건]  사망[명]
# 1                                                   합계       합계  24399    583
# 2                                                   합계      종로구     68      0
# 3                                                   합계       중구     57      0
# 4                                                   합계      용산구    135      4
# ..                                                 ...      ...    ...    ...
# 473                                                 경남  창원시(통합)    398     11
# 474                                                 제주       합계    466      8
# 475                                                 제주      제주시    341      4
# 476                                                 제주     서귀포시    125      4
# 477  출처) 한국도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합...      NaN    NaN    NaN
#
# ...

# %%
a2 = a1[a1['시도'].isin(['서울', '경기','인천'])]
a3 = a2[['시도','시군구','2015','2016','2017','2018','2019']]

a4= a3.reset_index(drop =True)
display(a4)
# Out:
#     시도   시군구  2015  2016  2017  2018  2019
# 0   서울    합계  3453  2874  2864  2856  2190
# 1   서울   종로구    68    77    70    63    48
# 2   서울    중구    57    51    39    70    30
# 3   서울   용산구   135   118   106   100    73
# 4   서울   성동구    88    80    79    85    61
# ..  ..   ...   ...   ...   ...   ...   ...
# 64  경기   군포시    78    55    63    59    30
# 65  경기  남양주시   228   226   206   212   164
# 66  경기   오산시   128    92   107   133    89
# 67  경기   의왕시    77    48    51    60    40
# 68  경기   하남시    79    62    62    60    67
#
# [69 rows x 7 columns]

# %%
a4.to_excel('지역별음주사고.xlsx',index = False)
