# %%
import pandas as pd
import numpy as np

# %%
a1 = pd.read_excel('C:/Users/이민정/OneDrive/바탕 화면/mid project/음주운전 관련 데이터/음주_교통사고_20-24.xls')
display(a1)
# Out:
#                                                     시도      시군구   2020 2020.1  \
# 0                                                   시도      시군구  사고[건]  사망[명]
# 1                                                   합계       합계  17247    287
# 2                                                   합계      종로구     47      0
# 3                                                   합계       중구     49      2
# 4                                                   합계      용산구     65      0
# ..                                                 ...      ...    ...    ...
# 475                                                 경남  창원시(통합)    253      8
# 476                                                 제주       합계    362      5
# 477                                                 제주      제주시    255      4
# 478                                                 제주     서귀포시    107      1
# 479  출처) 한국도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합...      NaN    NaN    NaN
#
# ...

# %%
a2 = a1[['시도','시군구','2020','2021','2022','2023','2024']]

a3 = a2[a2['시도'].isin(['서울', '경기', '인천'])]

a4 = a3.reset_index(drop = True)
display(a4)
# Out:
#     시도   시군구  2020  2021  2022  2023  2024
# 0   서울    합계  2327  2059  2348  1938  1576
# 1   서울   종로구    47    45    56    52    36
# 2   서울    중구    49    43    45    37    30
# 3   서울   용산구    65    72    94    64    73
# 4   서울   성동구    80    87    71    50    52
# ..  ..   ...   ...   ...   ...   ...   ...
# 64  경기   군포시    54    50    47    40    33
# 65  경기  남양주시   215   181   143   131   133
# 66  경기   오산시    89    89    84    79    64
# 67  경기   의왕시    48    36    50    27    31
# 68  경기   하남시    69    63    67    62    51
#
# [69 rows x 7 columns]

# %%
a4.to_excel('지역별음주운전20~24.xlsx', index = False)
